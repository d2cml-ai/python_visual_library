# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
data = pd.read_stata("https://github.com/worldbank/r-econ-visual-library/raw/master/Library/Data/evaluation.dta")

# %%
analysis_data = data[(data.eligible == 1) | (data.round == 1)]
analysis_data
# Out:
#        locality_identifier  household_identifier  treatment_locality  \
# 0                     26.0                   5.0                 1.0
# 1                     26.0                   5.0                 1.0
# 2                     26.0                  11.0                 1.0
# 3                     26.0                  11.0                 1.0
# 4                     26.0                  13.0                 1.0
# ...                    ...                   ...                 ...
# 11252                 40.0               15775.0                 1.0
# 11253                 40.0               15776.0                 1.0
# 11254                 40.0               15776.0                 1.0
# 11255                 40.0               15777.0                 1.0
# 11256                 40.0               15777.0                 1.0
#
#        promotion_locality  eligible  enrolled  enrolled_rp  poverty_index  \
# 0                     1.0       1.0       1.0          1.0      55.950542
# 1                     1.0       1.0       1.0          1.0      55.950542
# 2                     1.0       1.0       1.0          0.0      46.058731
# 3                     1.0       1.0       1.0          0.0      46.058731
# 4                     1.0       1.0       1.0          0.0      54.095825
# ...                   ...       ...       ...          ...            ...
# 11252                 1.0       1.0       1.0          1.0      37.171562
# 11253                 1.0       1.0       1.0          1.0      29.057186
# 11254                 1.0       1.0       1.0          1.0      29.057186
# 11255                 1.0       1.0       1.0          1.0      38.485317
# 11256                 1.0       1.0       1.0          1.0      38.485317
#
#        round  health_expenditures  ...  educ_hh  educ_sp  female_hh  \
# 0        0.0            15.185455  ...      0.0      6.0        0.0
# 1        1.0            19.580902  ...      0.0      6.0        0.0
# 2        0.0            13.076257  ...      4.0      0.0        0.0
# 3        1.0             2.398854  ...      4.0      0.0        0.0
# 4        1.0             0.000000  ...      0.0      0.0        0.0
# ...      ...                  ...  ...      ...      ...        ...
# 11252    0.0            10.391406  ...      1.0      6.0        0.0
# 11253    0.0             8.679602  ...      0.0      2.0        0.0
# 11254    1.0             0.000000  ...      0.0      2.0        0.0
# 11255    1.0             0.000000  ...      4.0      2.0        0.0
# 11256    0.0            10.106905  ...      4.0      2.0        0.0
#
#        indigenous  hhsize  dirtfloor  bathroom  land  hospital_distance  \
# 0             0.0     4.0          1         0     1         124.819966
# 1             0.0     4.0          1         0     1         124.819966
# 2             0.0     6.0          1         0     2         124.819966
# 3             0.0     6.0          1         0     2         124.819966
# 4             0.0     6.0          1         0     4         124.819966
# ...           ...     ...        ...       ...   ...                ...
# 11252         1.0     6.0          1         1     0         114.763392
# 11253         1.0     9.0          1         0     0         114.763392
# 11254         1.0     9.0          1         0     0         114.763392
# 11255         1.0     6.0          1         0     0         114.763392
# 11256         1.0     6.0          1         0     0         114.763392
#
#        hospital
# 0           0.0
# 1           0.0
# 2           0.0
# 3           1.0
# 4           1.0
# ...         ...
# 11252       0.0
# 11253       0.0
# 11254       0.0
# 11255       0.0
# 11256       0.0
#
# [11257 rows x 22 columns]
